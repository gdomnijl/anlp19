# %% [markdown]
# This notebook explores feature engineering for text classification.  Your task is to create two new feature functions (like `dictionary_feature` and `unigram_feature` below), and include them in the `build_features` function.  A check grade will be given to generic features that apply across arbitrary text classification problems (e.g., a feature for bigrams); check+ will be given for at least one feature that reveals your own understanding of your data. What features do you think will help for your particular problem? Your grade is *not* tied to whether accuracy goes up or down, so be creative!  You are free to read in any other external resources you like (dictionaries, document metadata, etc.)

# %% [markdown]
# Q0: Briefly describe your data (including the categories you're predicting)

# %%
import sys
from collections import Counter
from sklearn import preprocessing
from sklearn import linear_model
import pandas as pd
from scipy import sparse
import numpy as np
from nltk.tokenize import casual_tokenize

# %%
def read_data(filename):
    X=[]
    Y=[]
    with open(filename, encoding="utf-8") as file:
        for line in file:
            cols=line.rstrip().split("\t")
            label=cols[0]
            text=cols[1]
            X.append(text)
            Y.append(label)
    return X, Y

# %%
# Change this to the directory with your data (from the CheckData_TODO.ipynb exercise).  
# The directory should contain train.tsv, dev.tsv and test.tsv
directory="../data/text_classification_sample_data"
yahoo_dir = "../data/text_classification/yahoo"

# %%
trainX, trainY=read_data("%s/train.tsv" % yahoo_dir)
devX, devY=read_data("%s/dev.tsv" % yahoo_dir)

# %%
data = pd.DataFrame({"qn": trainX, "label": trainY})

# %%
data[data.label=='1']
# Out:
#                                                     qn label
# 0               Did you hear about my buddy Bill Fold?     1
# 1       Does the word 'prego' or 'preggers' annoy you?     1
# 3                      Fancy Dress ideas for Bestival?     1
# 7      What will happen when we run out of lolliepops?     1
# 8    What's the absolutely funniest cat video ever?...     1
# 15   Question about the show 'The Boondocks' on Car...     1
# 16   Can evolution and Christianity really coexist ...     1
# 17                          How to succeed in  the us?     1
# 18   What's some prons and cons of being a Lesbian ...     1
# 19     Now read this freestyle poem for some of yall.?     1
# 26   Anyone else excited about CM Punk vs. Rey Myst...     1
# 31          Is my boyfriend shy, or is he avoiding me?     1
# 33                           Why do you hate breeders?     1
# 36                   i'm not ready to date right now??     1
# 38   What are some of the resolutions to suspend th...     1
# 39   Spiritually Wondering, what is a practical way...     1
# 46   which of these names do you like better for a ...     1
# 47   How can God have emotions, yet create other be...     1
# 50        Is it true that the Missouri college fiasco?     1
# 51         Boston Celtics 2011 Playoffs (Boston Fans)?     1
# 55     We are married, in love, but living separately?     1
# 56                           how can i save the earth?     1
# 59                 I'm thinking of getting a suit but?     1
# 60          Should the Bush Administration be charged?     1
# 62                                 Names please help!?     1
# 64                                  i need some help??     1
# 66   I was asked to return to my home town and give...     1
# 68                      I want the world to know me..?     1
# 69   My neighbour Pippa Strelle, keeps doing somers...     1
# 70   Do you think it's going to be fierce payback t...     1
# ..                                                 ...   ...
# 749  what should i do.. he cheated on me forever ag...     1
# 750                              Buying a fixer upper?     1
# 751  Phone etiquette help......what should i talk w...     1
# 754  Ladies, what strain or type of bud do you like...     1
# 755  Since Braq Obama's brother Odinga is a Shari C...     1
# 759  Why oh Why Bradman is the most overrated batsm...     1
# 760  "Exactly how did the State Department threaten...     1
# 762  R&S: What's your IQ and are you an Atheist or ...     1
# 763  Have you been to Hungary? If so, what was your...     1
# 764  How do you make a girl want to have a sexual r...     1
# 765  What'd you think of this crossover where Derri...     1
# 766  If a girl rejects a guy. Does she remember and...     1
# 767  Do you think torture is in step with our Chris...     1
# 770  please help me..if a girl i know gets nervous ...     1
# 773  i fancy my best friend and want to do sexual a...     1
# 774           should i take him back does he want me ?     1
# 776          Should I investigate, or let him slip up?     1
# 779             growth for 15 year old ? please help ?     1
# 782  This question has been posted all night`, Prec...     1
# 785                     I need a name???? PLEASE HELP?     1
# 787  10pts-GIRLS-WOMEN---your advice on HOT BAD BOY...     1
# 789     How can I find a coach I had last year.......?     1
# 790                   Looking for opinions on a fight?     1
# 791  How to know if a bestfriend still cares for yo...     1
# 792  I had only one love in my life, l can love again?     1
# 793         Relationship advice.. I'm falling in love?     1
# 797                 Did Barack Obama cheat John Kerry?     1
# 802  Why hasnt Dana White signed Butterbean for the...     1
# 806  I've had this stye since Sunday morning and to...     1
# 815  When you see a homeless guy with a dog, do you...     1
#
# [360 rows x 2 columns]

# %%
def majority_class(trainY, devY):
    labelCounts=Counter()
    for label in trainY:
        labelCounts[label]+=1
    majority=labelCounts.most_common(1)[0][0]
    
    correct=0.
    for label in devY:
        if label == majority:
            correct+=1
            
    print("%s\t%.3f" % (majority, correct/len(devY)))

# %% [markdown]
# Here we'll create two feature classes -- one feature class noting the presence of a word in an external dictionary, and one feature class for the word identity (i.e., unigram).  We'll implement each feature class as a function that takes a single document as input (as a list of tokens) and returns a dict corresponding to the feature we're creating.

# %%
# Here's a sample dictionary we can create by inspecting the output of the Mann-Whitney test (in 2.compare/)
dem_dictionary=set(["republican","cut", "opposition"])
repub_dictionary=set(["growth","economy"])

def political_dictionary_feature(tokens):
    feats={}
    for word in tokens:
        if word in dem_dictionary:
            feats["word_in_dem_dictionary"]=1
        if word in repub_dictionary:
            feats["word_in_repub_dictionary"]=1
    return feats

# %%
def unigram_feature(tokens):
    feats={}
    for word in tokens:
        feats["UNIGRAM_%s" % word]=1
    return feats

# %% [markdown]
# Q1: Add first new feature function here.  Describe your feature and why you think it will help.

# %% [markdown]
# A note that I have found a new dataset that interests me more. It is a set of quesions (~1000) asked on Yahoo Answers platform. Each question is labeled as 0 if it is informational, 1 if it is conversational.

# %% [markdown]
# The first feature I am creating is the number of second-person pronouns in the questions that are strongly indicative of conversational intention, for example, "you", "your". After a few experimentations, I also added in third-person pronouns which improved prediction.

# %%
PRONOUNS = ['you', 'your', 'he', 'him', 'his', 'she', 'her', 'hers', 'they', 'their', 'theirs']
def new_feature_class_one(tokens):
    feats={}
    num_pronouns = 0
    for word in tokens:
        if word in PRONOUNS:
            num_pronouns += 1
    
    feats["num_pronouns"]= num_pronouns 
    return feats

# %% [markdown]
# Q2: Add second new feature function here. Describe your feature and why you think it will help.

# %%
## Tried word count, it was bad
## Sentiment polarity?
POLAR_THRESHOLD = 2
def read_AFINN_dictionary(filename):
    neutral=[]
    polar=[]
    with open(filename) as file:
        for line in file:
            cols=line.rstrip().split("\t")
            word=cols[0]
            value=int(cols[1])
            if value < -POLAR_THRESHOLD or value > POLAR_THRESHOLD:
                polar.append(word)
            else:
                neutral.append(word)
    
    return set(neutral), set(polar)
neutral, polar=read_AFINN_dictionary("../data/AFINN-111.txt")

def new_feature_class_two(tokens):
    feats={}
    num_polar = 0
    num_neutral = 0
    for word in tokens:
        if word in neutral:
            num_neutral +=1
        if word in polar:
            num_polar +=1
    feats["num_polar"] = num_polar
    #feats['num_neutral']  = num_neutral
    return feats

# %% [markdown]
# This is the main function we'll use to aggregate together all of the information from different feature classes.  Each document has a feature dict (`feats`), and we'll update that dict with the new dict that each separate feature class is returning.  (Here you want to make sure that the keys each feature function is creating are unique so they don't get clobbered by other functions).

# %%
## my notes: This is creating a dictionary of feature values for each row
def build_features(trainX, feature_functions):
    data=[]

    ## creating feature values row by row
    for doc in trainX:
        feats={}

        # sample text data is already tokenized; if yours is not, do so here
        
        tokens=list(map(lambda x: x.lower(), casual_tokenize(doc)))
        ## TODO: in the future, can preprocess more (words attached to punctuation)
        
        for function in feature_functions:
            feats.update(function(tokens))

        data.append(feats)
    return data

# %%
# **** my note: mapping each unseen feature to an index along the way 
# This helper function converts a dictionary of feature names to unique numerical ids
def create_vocab(data):
    feature_vocab={}
    idx=0
    for doc in data:
        for feat in doc:
            if feat not in feature_vocab:
                feature_vocab[feat]=idx
                idx+=1
                
    return feature_vocab

# %%
# my note: finally understood what this is doing; lil_matrix is like a interface to represent sparse matrix 
# using efficient data structure such as linked list

# This helper function converts a dictionary of feature names to a sparse representation
# that we can fit in a scikit-learn model.  This is important because almost all feature 
# values will be 0 for most documents (note: why?), and we don't want to save them all in 
# memory.

def features_to_ids(data, feature_vocab):
    new_data=sparse.lil_matrix((len(data), len(feature_vocab)))
    for idx,doc in enumerate(data):
        for f in doc:
            if f in feature_vocab:
                new_data[idx,feature_vocab[f]]=doc[f]
    return new_data

# %%
# This function evaluates a list of feature functions on the training/dev data arguments
def pipeline(trainX, devX, trainY, devY, feature_functions):
    trainX_feat=build_features(trainX, feature_functions)
    devX_feat=build_features(devX, feature_functions)

    # just create vocabulary from features in *training* data
    feature_vocab=create_vocab(trainX_feat)

    trainX_ids=features_to_ids(trainX_feat, feature_vocab)
    devX_ids=features_to_ids(devX_feat, feature_vocab)
    
    logreg = linear_model.LogisticRegression(C=1.0, solver='lbfgs', penalty='l2', max_iter=10000)
    logreg.fit(trainX_ids, trainY)
    print("Accuracy: %.3f" % logreg.score(devX_ids, devY))  
    return logreg, feature_vocab

# %%
majority_class(trainY,devY)
# Out:
# 0	0.559

# %% [markdown]
# Explore the impact of different feature functions by evaluating them below:

# %%
features=[political_dictionary_feature]
pipeline(trainX, devX, trainY, devY, features)

## This equals the baseline because the politic-affliated words prob didn't appear in the text at all
# Out:
# Accuracy: 0.559

# %%
features=[political_dictionary_feature, unigram_feature]
mod, feature_dict = pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.725

# %% [markdown]
# ## This is for my own investigation:

# %%
tb  = pd.DataFrame({"coef": mod.coef_[0], "feature": list(feature_dict.keys())})
print("Most informational unigrams:")
print(tb.sort_values(by = "coef")[:15])
print("\nMost conversational unigrams:")
print(tb.sort_values(by = "coef", ascending = False)[:15])
# Out:
# Most informational unigrams:
#           coef           feature
# 92   -1.210408  UNIGRAM_pregnant
# 43   -0.981028      UNIGRAM_help
# 184  -0.973434      UNIGRAM_from
# 165  -0.948730      UNIGRAM_math
# 35   -0.906279     UNIGRAM_where
# 1088 -0.856271       UNIGRAM_car
# 283  -0.850324  UNIGRAM_computer
# 378  -0.688535      UNIGRAM_song
# 17   -0.684154       UNIGRAM_how
# 200  -0.679598        UNIGRAM_it
# 880  -0.678904  UNIGRAM_dandruff
# 1383 -0.672418       UNIGRAM_i'd
# 833  -0.668898   UNIGRAM_macbook
# 1621 -0.666162    UNIGRAM_iphone
# 1441 -0.658944    UNIGRAM_emails
#
# Most conversational unigrams:
#           coef             feature
# 292   1.262289       UNIGRAM_names
# 295   1.260988        UNIGRAM_girl
# 750   1.220323        UNIGRAM_year
# 638   1.181029       UNIGRAM_don't
# 1307  1.173219  UNIGRAM_girlfriend
# 54    1.090171          UNIGRAM_we
# 1     1.075641         UNIGRAM_you
# 397   1.057599       UNIGRAM_think
# 209   1.052321          UNIGRAM_he
# 1445  1.024545      UNIGRAM_scared
# 239   1.018263      UNIGRAM_should
# 84    1.013533          UNIGRAM_so
# 713   1.003208         UNIGRAM_say
# 807   0.955858     UNIGRAM_parents
# 819   0.931575        UNIGRAM_deal

# %%
features=[new_feature_class_one]
mod1, f_dict1 = pipeline(trainX, devX, trainY, devY, features)
print("coefficient for presence of second-person pronouns %f" % mod1.coef_)
# Out:
# Accuracy: 0.686
# coefficient for presence of second-person pronouns 0.906653

# %%
features=[unigram_feature, new_feature_class_one]
mod1, f_dict1 = pipeline(trainX, devX, trainY, devY, features)
tb1  = pd.DataFrame({"coef": mod1.coef_[0], "feature": list(f_dict1.keys())})
print("Most informational features:")
print(tb1.sort_values(by = "coef")[:15])
print("\nMost conversational features:")
print(tb1.sort_values(by = "coef", ascending = False)[:15])
# Out:
# Accuracy: 0.735
# Most informational features:
#           coef           feature
# 93   -1.210675  UNIGRAM_pregnant
# 185  -1.008397      UNIGRAM_from
# 36   -0.994127     UNIGRAM_where
# 44   -0.970349      UNIGRAM_help
# 166  -0.940137      UNIGRAM_math
# 284  -0.840340  UNIGRAM_computer
# 1089 -0.827120       UNIGRAM_car
# 201  -0.762077        UNIGRAM_it
# 379  -0.727824      UNIGRAM_song
# 274  -0.722435         UNIGRAM_x
# 18   -0.691610       UNIGRAM_how
# 222  -0.688498     UNIGRAM_sites
# 881  -0.676616  UNIGRAM_dandruff
# 1622 -0.669261    UNIGRAM_iphone
# 1384 -0.666510       UNIGRAM_i'd
#
# Most conversational features:
#           coef             feature
# 296   1.276150        UNIGRAM_girl
# 751   1.270171        UNIGRAM_year
# 293   1.244788       UNIGRAM_names
# 1308  1.153987  UNIGRAM_girlfriend
# 639   1.152731       UNIGRAM_don't
# 55    1.123358          UNIGRAM_we
# 9     1.099396        num_pronouns
# 398   1.048428       UNIGRAM_think
# 85    0.999019          UNIGRAM_so
# 1446  0.983579      UNIGRAM_scared
# 820   0.937461        UNIGRAM_deal
# 808   0.935990     UNIGRAM_parents
# 240   0.923173      UNIGRAM_should
# 550   0.896075         UNIGRAM_who
# 125   0.867427        UNIGRAM_some

# %%
features=[new_feature_class_two]
mod2, f_dict2 = pipeline(trainX, devX, trainY, devY, features)
mod2.coef_
# Out:
# Accuracy: 0.608
# array([[0.68315631]])

# %%
features=[new_feature_class_one, new_feature_class_two]
pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.725
# (LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=10000, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='lbfgs', tol=0.0001,
#            verbose=0, warm_start=False), {'num_polar': 1, 'num_pronouns': 0})

# %%
features=[unigram_feature, new_feature_class_one, new_feature_class_two]
pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.716
# (LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=10000, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='lbfgs', tol=0.0001,
#            verbose=0, warm_start=False),
#  {'UNIGRAM_did': 0,
#   'UNIGRAM_you': 1,
#   'UNIGRAM_hear': 2,
#   'UNIGRAM_about': 3,
#   'UNIGRAM_my': 4,
#   'UNIGRAM_buddy': 5,
#   'UNIGRAM_bill': 6,
#   'UNIGRAM_fold': 7,
#   'UNIGRAM_?': 8,
#   'num_pronouns': 9,
#   'word_count': 10,
#   'UNIGRAM_does': 11,
#   'UNIGRAM_the': 12,
#   'UNIGRAM_word': 13,
#   "UNIGRAM_'": 14,
#   'UNIGRAM_prego': 15,
#   'UNIGRAM_or': 16,
#   'UNIGRAM_preggers': 17,
#   'UNIGRAM_annoy': 18,
#   'UNIGRAM_how': 19,
#   'UNIGRAM_to': 20,
#   'UNIGRAM_draw': 21,
#   'UNIGRAM_goth': 22,
#   'UNIGRAM_anime': 23,
#   'UNIGRAM_girls': 24,
#   'UNIGRAM_fancy': 25,
#   'UNIGRAM_dress': 26,
#   'UNIGRAM_ideas': 27,
#   'UNIGRAM_for': 28,
#   'UNIGRAM_bestival': 29,
#   'UNIGRAM_can': 30,
#   'UNIGRAM_i': 31,
#   'UNIGRAM_get': 32,
#   'UNIGRAM_yahoo': 33,
#   'UNIGRAM_chat': 34,
#   'UNIGRAM_work': 35,
#   'UNIGRAM_,': 36,
#   'UNIGRAM_where': 37,
#   'UNIGRAM_do': 38,
#   'UNIGRAM_correct': 39,
#   'UNIGRAM_java': 40,
#   'UNIGRAM_find': 41,
#   'UNIGRAM_a': 42,
#   'UNIGRAM_job': 43,
#   'UNIGRAM_need': 44,
#   'UNIGRAM_help': 45,
#   'UNIGRAM_what': 46,
#   'UNIGRAM_is': 47,
#   'UNIGRAM_differences': 48,
#   'UNIGRAM_and': 49,
#   'UNIGRAM_similarities': 50,
#   'UNIGRAM_mri': 51,
#   'UNIGRAM_ct': 52,
#   'UNIGRAM_will': 53,
#   'UNIGRAM_happen': 54,
#   'UNIGRAM_when': 55,
#   'UNIGRAM_we': 56,
#   'UNIGRAM_run': 57,
#   'UNIGRAM_out': 58,
#   'UNIGRAM_of': 59,
#   'UNIGRAM_lolliepops': 60,
#   "UNIGRAM_what's": 61,
#   'UNIGRAM_absolutely': 62,
#   'UNIGRAM_funniest': 63,
#   'UNIGRAM_cat': 64,
#   'UNIGRAM_video': 65,
#   'UNIGRAM_ever': 66,
#   'UNIGRAM_!': 67,
#   'UNIGRAM_post': 68,
#   'UNIGRAM_link': 69,
#   'UNIGRAM_:)': 70,
#   'UNIGRAM_cell': 71,
#   'UNIGRAM_phone': 72,
#   'UNIGRAM_only': 73,
#   'UNIGRAM_two': 74,
#   'UNIGRAM_months': 75,
#   'UNIGRAM_with': 76,
#   'UNIGRAM_0': 77,
#   'UNIGRAM_minutes': 78,
#   'UNIGRAM_unlimited': 79,
#   'UNIGRAM_texting': 80,
#   'UNIGRAM_.': 81,
#   'UNIGRAM_dad': 82,
#   'UNIGRAM_accidentally': 83,
#   'UNIGRAM_hurt': 84,
#   'UNIGRAM_bird': 85,
#   'UNIGRAM_so': 86,
#   'UNIGRAM_us': 87,
#   'UNIGRAM_size': 88,
#   'UNIGRAM_37': 89,
#   'UNIGRAM_female': 90,
#   'UNIGRAM_shoe': 91,
#   'UNIGRAM_could': 92,
#   'UNIGRAM_be': 93,
#   'UNIGRAM_pregnant': 94,
#   'UNIGRAM_please': 95,
#   'UNIGRAM_last': 96,
#   'UNIGRAM_call': 97,
#   'UNIGRAM_not': 98,
#   'UNIGRAM_hang': 99,
#   'UNIGRAM_up': 100,
#   'UNIGRAM_on': 101,
#   'UNIGRAM_their': 102,
#   'UNIGRAM_end-can': 103,
#   'UNIGRAM_use': 104,
#   'UNIGRAM_brujah': 105,
#   'UNIGRAM_question': 106,
#   'UNIGRAM_show': 107,
#   'UNIGRAM_boondocks': 108,
#   'UNIGRAM_cartoon': 109,
#   'UNIGRAM_network': 110,
#   'UNIGRAM_evolution': 111,
#   'UNIGRAM_christianity': 112,
#   'UNIGRAM_really': 113,
#   'UNIGRAM_coexist': 114,
#   'UNIGRAM_there': 115,
#   'UNIGRAM_being': 116,
#   'UNIGRAM_an': 117,
#   'UNIGRAM_adam': 118,
#   'UNIGRAM_eve': 119,
#   'UNIGRAM_make': 120,
#   "UNIGRAM_jesus's": 121,
#   'UNIGRAM_sacrifice': 122,
#   'UNIGRAM_meaningless': 123,
#   'UNIGRAM_succeed': 124,
#   'UNIGRAM_in': 125,
#   'UNIGRAM_some': 126,
#   'UNIGRAM_prons': 127,
#   'UNIGRAM_cons': 128,
#   'UNIGRAM_lesbian': 129,
#   'UNIGRAM_your': 130,
#   'UNIGRAM_opinion': 131,
#   'UNIGRAM_now': 132,
#   'UNIGRAM_read': 133,
#   'UNIGRAM_this': 134,
#   'UNIGRAM_freestyle': 135,
#   'UNIGRAM_poem': 136,
#   'UNIGRAM_yall': 137,
#   'UNIGRAM_sim': 138,
#   'UNIGRAM_provisioned': 139,
#   'UNIGRAM_mm': 140,
#   'UNIGRAM_#': 141,
#   'UNIGRAM_2': 142,
#   'UNIGRAM_mean': 143,
#   'UNIGRAM_cellphone': 144,
#   'UNIGRAM_duty': 145,
#   'UNIGRAM_modern': 146,
#   'UNIGRAM_warfare': 147,
#   'UNIGRAM_(': 148,
#   'UNIGRAM_xbox': 149,
#   'UNIGRAM_360': 150,
#   'UNIGRAM_)': 151,
#   'UNIGRAM_send': 152,
#   'UNIGRAM_email': 153,
#   'UNIGRAM_friend': 154,
#   'UNIGRAM_her': 155,
#   'UNIGRAM_but': 156,
#   'UNIGRAM_fast': 157,
#   'UNIGRAM_by': 158,
#   'UNIGRAM_hot': 159,
#   'UNIGRAM_mail': 160,
#   'UNIGRAM_"': 161,
#   "UNIGRAM_what're": 162,
#   'UNIGRAM_real': 163,
#   'UNIGRAM_mac': 164,
#   'UNIGRAM_brown': 165,
#   'UNIGRAM_eyeshadows': 166,
#   'UNIGRAM_math': 167,
#   'UNIGRAM_:': 168,
#   'UNIGRAM_partial': 169,
#   'UNIGRAM_differential': 170,
#   'UNIGRAM_equations': 171,
#   'UNIGRAM_anyone': 172,
#   'UNIGRAM_else': 173,
#   'UNIGRAM_excited': 174,
#   'UNIGRAM_cm': 175,
#   'UNIGRAM_punk': 176,
#   'UNIGRAM_vs': 177,
#   'UNIGRAM_rey': 178,
#   'UNIGRAM_mysterio': 179,
#   'UNIGRAM_tell': 180,
#   'UNIGRAM_if': 181,
#   'UNIGRAM_dog': 182,
#   'UNIGRAM_has': 183,
#   'UNIGRAM_arthritis': 184,
#   'UNIGRAM_items': 185,
#   'UNIGRAM_from': 186,
#   'UNIGRAM_amazon': 187,
#   'UNIGRAM_uk': 188,
#   'UNIGRAM_ship': 189,
#   'UNIGRAM_u': 190,
#   'UNIGRAM_s': 191,
#   'UNIGRAM_husband': 192,
#   'UNIGRAM_had': 193,
#   'UNIGRAM_unsafe': 194,
#   'UNIGRAM_sex': 195,
#   'UNIGRAM_night': 196,
#   'UNIGRAM_prior': 197,
#   'UNIGRAM_period': 198,
#   'UNIGRAM_got': 199,
#   'UNIGRAM_next': 200,
#   'UNIGRAM_day': 201,
#   'UNIGRAM_it': 202,
#   'UNIGRAM_still': 203,
#   'UNIGRAM_safe': 204,
#   'UNIGRAM_accounting': 205,
#   'UNIGRAM_no': 206,
#   'UNIGRAM_fun': 207,
#   'UNIGRAM_:(': 208,
#   'UNIGRAM_boyfriend': 209,
#   'UNIGRAM_shy': 210,
#   'UNIGRAM_he': 211,
#   'UNIGRAM_avoiding': 212,
#   'UNIGRAM_me': 213,
#   'UNIGRAM_33': 214,
#   'UNIGRAM_weeks': 215,
#   'UNIGRAM_why': 216,
#   'UNIGRAM_hate': 217,
#   'UNIGRAM_breeders': 218,
#   'UNIGRAM_compost': 219,
#   'UNIGRAM_more': 220,
#   'UNIGRAM_acidic': 221,
#   'UNIGRAM_know': 222,
#   'UNIGRAM_sites': 223,
#   'UNIGRAM_babyshowers': 224,
#   "UNIGRAM_i'm": 225,
#   'UNIGRAM_ready': 226,
#   'UNIGRAM_date': 227,
#   'UNIGRAM_right': 228,
#   'UNIGRAM_nokia': 229,
#   'UNIGRAM_5130': 230,
#   'UNIGRAM_browser': 231,
#   "UNIGRAM_won't": 232,
#   'UNIGRAM_start': 233,
#   'UNIGRAM_problem': 234,
#   'UNIGRAM_are': 235,
#   'UNIGRAM_resolutions': 236,
#   'UNIGRAM_suspend': 237,
#   'UNIGRAM_state': 238,
#   'UNIGRAM_gasoline': 239,
#   'UNIGRAM_tax': 240,
#   'UNIGRAM_should': 241,
#   'UNIGRAM_that': 242,
#   'UNIGRAM_spiritually': 243,
#   'UNIGRAM_wondering': 244,
#   'UNIGRAM_practical': 245,
#   'UNIGRAM_way': 246,
#   'UNIGRAM_fixing': 247,
#   'UNIGRAM_problems': 248,
#   'UNIGRAM_world': 249,
#   'UNIGRAM_im': 250,
#   'UNIGRAM_15': 251,
#   'UNIGRAM_become': 252,
#   'UNIGRAM_16': 253,
#   'UNIGRAM_deciding': 254,
#   'UNIGRAM_becoming': 255,
#   'UNIGRAM_emancipated': 256,
#   'UNIGRAM_moving': 257,
#   'UNIGRAM_emancipation': 258,
#   'UNIGRAM_carry': 259,
#   'UNIGRAM_over': 260,
#   'UNIGRAM_another': 261,
#   "UNIGRAM_i've": 262,
#   'UNIGRAM_active': 263,
#   'UNIGRAM_wharfedale': 264,
#   'UNIGRAM_sub': 265,
#   'UNIGRAM_amp': 266,
#   'UNIGRAM_longer': 267,
#   'UNIGRAM_working': 268,
#   'UNIGRAM_speaker': 269,
#   'UNIGRAM_part': 270,
#   'UNIGRAM_detached': 271,
#   'UNIGRAM_...': 272,
#   'UNIGRAM_was': 273,
#   'UNIGRAM_malcolm': 274,
#   'UNIGRAM_x': 275,
#   'UNIGRAM_considered': 276,
#   'UNIGRAM_at': 277,
#   'UNIGRAM_civil': 278,
#   'UNIGRAM_rights': 279,
#   'UNIGRAM_leader': 280,
#   'UNIGRAM_someone': 281,
#   'UNIGRAM_other': 282,
#   'UNIGRAM_than': 283,
#   'UNIGRAM_myself': 284,
#   'UNIGRAM_computer': 285,
#   'UNIGRAM_zebra': 286,
#   'UNIGRAM_tie': 287,
#   'UNIGRAM_am': 288,
#   'UNIGRAM_seeing': 289,
#   'UNIGRAM_shadow': 290,
#   'UNIGRAM_people': 291,
#   'UNIGRAM_which': 292,
#   'UNIGRAM_these': 293,
#   'UNIGRAM_names': 294,
#   'UNIGRAM_like': 295,
#   'UNIGRAM_better': 296,
#   'UNIGRAM_girl': 297,
#   'UNIGRAM_god': 298,
#   'UNIGRAM_have': 299,
#   'UNIGRAM_emotions': 300,
#   'UNIGRAM_yet': 301,
#   'UNIGRAM_create': 302,
#   'UNIGRAM_beings': 303,
#   'UNIGRAM_same': 304,
#   'UNIGRAM_doesnt': 305,
#   'UNIGRAM_himself': 306,
#   'UNIGRAM_creator': 307,
#   'UNIGRAM_point': 308,
#   'UNIGRAM_able': 309,
#   'UNIGRAM_beat': 310,
#   'UNIGRAM_times': 311,
#   'UNIGRAM_system': 312,
#   'UNIGRAM_recovery': 313,
#   'UNIGRAM_windows': 314,
#   'UNIGRAM_xp': 315,
#   'UNIGRAM_true': 316,
#   'UNIGRAM_missouri': 317,
#   'UNIGRAM_college': 318,
#   'UNIGRAM_fiasco': 319,
#   'UNIGRAM_boston': 320,
#   'UNIGRAM_celtics': 321,
#   'UNIGRAM_2011': 322,
#   'UNIGRAM_playoffs': 323,
#   'UNIGRAM_fans': 324,
#   'UNIGRAM_migrate': 325,
#   'UNIGRAM_database': 326,
#   'UNIGRAM_connections': 327,
#   'UNIGRAM_see': 328,
#   'UNIGRAM_questions': 329,
#   'UNIGRAM_ask': 330,
#   'UNIGRAM_buy': 331,
#   'UNIGRAM_chocolate': 332,
#   'UNIGRAM_wet': 333,
#   'UNIGRAM_n': 334,
#   'UNIGRAM_wavy': 335,
#   'UNIGRAM_weave': 336,
#   'UNIGRAM_married': 337,
#   'UNIGRAM_love': 338,
#   'UNIGRAM_living': 339,
#   'UNIGRAM_separately': 340,
#   'UNIGRAM_save': 341,
#   'UNIGRAM_earth': 342,
#   'UNIGRAM_arizona': 343,
#   'UNIGRAM_tea': 344,
#   'UNIGRAM_cans': 345,
#   'UNIGRAM_refundable': 346,
#   'UNIGRAM_rt': 347,
#   'UNIGRAM_tweets': 348,
#   'UNIGRAM_thinking': 349,
#   'UNIGRAM_getting': 350,
#   'UNIGRAM_suit': 351,
#   'UNIGRAM_bush': 352,
#   'UNIGRAM_administration': 353,
#   'UNIGRAM_charged': 354,
#   'UNIGRAM_dont': 355,
#   'UNIGRAM_appt': 356,
#   'UNIGRAM_ob': 357,
#   'UNIGRAM_til': 358,
#   'UNIGRAM_14th': 359,
#   'UNIGRAM_abdomin': 360,
#   'UNIGRAM_lower': 361,
#   'UNIGRAM_back': 362,
#   'UNIGRAM_pain': 363,
#   'UNIGRAM_christians': 364,
#   'UNIGRAM_exactly': 365,
#   'UNIGRAM_offer': 366,
#   'UNIGRAM_blood': 367,
#   'UNIGRAM_jesus': 368,
#   'UNIGRAM_geography': 369,
#   'UNIGRAM_canadian': 370,
#   'UNIGRAM_asked': 371,
#   'UNIGRAM_return': 372,
#   'UNIGRAM_home': 373,
#   'UNIGRAM_town': 374,
#   'UNIGRAM_give': 375,
#   'UNIGRAM_speech': 376,
#   'UNIGRAM_hs': 377,
#   'UNIGRAM_students': 378,
#   'UNIGRAM_diversity': 379,
#   'UNIGRAM_song': 380,
#   'UNIGRAM_fiancee': 381,
#   'UNIGRAM_army': 382,
#   "UNIGRAM_can't": 383,
#   'UNIGRAM_him': 384,
#   'UNIGRAM_want': 385,
#   'UNIGRAM_..': 386,
#   'UNIGRAM_neighbour': 387,
#   'UNIGRAM_pippa': 388,
#   'UNIGRAM_strelle': 389,
#   'UNIGRAM_keeps': 390,
#   'UNIGRAM_doing': 391,
#   'UNIGRAM_somersaults': 392,
#   'UNIGRAM_flik': 393,
#   'UNIGRAM_flaks': 394,
#   'UNIGRAM_masonry': 395,
#   'UNIGRAM_support': 396,
#   'UNIGRAM_she': 397,
#   'UNIGRAM_-': 398,
#   'UNIGRAM_think': 399,
#   "UNIGRAM_it's": 400,
#   'UNIGRAM_going': 401,
#   'UNIGRAM_fierce': 402,
#   'UNIGRAM_payback': 403,
#   'UNIGRAM_time': 404,
#   'UNIGRAM_obama': 405,
#   'UNIGRAM_office': 406,
#   'UNIGRAM_expat': 407,
#   'UNIGRAM_citizen': 408,
#   'UNIGRAM_hired': 409,
#   'UNIGRAM_employer': 410,
#   'UNIGRAM_illegal': 411,
#   'UNIGRAM_teacher': 412,
#   'UNIGRAM_go': 413,
#   'UNIGRAM_through': 414,
#   'UNIGRAM_snapchat': 415,
#   'UNIGRAM_trouble': 416,
#   'UNIGRAM_possible': 417,
#   'UNIGRAM_chances': 418,
#   'UNIGRAM_>': 419,
#   'UNIGRAM_singapore': 420,
#   'UNIGRAM_different': 421,
#   'UNIGRAM_australia': 422,
#   'UNIGRAM_good': 423,
#   'UNIGRAM_youtube': 424,
#   'UNIGRAM_user': 425,
#   'UNIGRAM_average': 426,
#   'UNIGRAM_inflation': 427,
#   'UNIGRAM_cris': 428,
#   'UNIGRAM_carter': 429,
#   'UNIGRAM_warren': 430,
#   'UNIGRAM_sapp': 431,
#   'UNIGRAM_cocaine': 432,
#   'UNIGRAM_hall': 433,
#   'UNIGRAM_fame': 434,
#   'UNIGRAM_party': 435,
#   'UNIGRAM_guys': 436,
#   'UNIGRAM_dislike': 437,
#   'UNIGRAM_bed': 438,
#   'UNIGRAM_chick': 439,
#   'UNIGRAM_holy': 440,
#   'UNIGRAM_$': 441,
#   'UNIGRAM_*': 442,
#   'UNIGRAM_@': 443,
#   'UNIGRAM_luck': 444,
#   'UNIGRAM_together': 445,
#   'UNIGRAM_forever': 446,
#   'UNIGRAM_too': 447,
#   'UNIGRAM_short': 448,
#   'UNIGRAM_marines': 449,
#   'UNIGRAM_would': 450,
#   'UNIGRAM_bad': 451,
#   'UNIGRAM_reason': 452,
#   'UNIGRAM_revolution': 453,
#   'UNIGRAM_ps3': 454,
#   'UNIGRAM_games': 455,
#   'UNIGRAM_rent': 456,
#   'UNIGRAM_battlefield': 457,
#   'UNIGRAM_3': 458,
#   'UNIGRAM_come': 459,
#   'UNIGRAM_journalists': 460,
#   'UNIGRAM_just': 461,
#   'UNIGRAM_professional': 462,
#   'UNIGRAM_sh': 463,
#   'UNIGRAM_t': 464,
#   'UNIGRAM_stirrers': 465,
#   'UNIGRAM_gossips': 466,
#   'UNIGRAM_kind': 467,
#   'UNIGRAM_hairstyle': 468,
#   'UNIGRAM_canon': 469,
#   'UNIGRAM_rebel': 470,
#   'UNIGRAM_t5i': 471,
#   'UNIGRAM_remove': 472,
#   'UNIGRAM_denture': 473,
#   'UNIGRAM_adhesive': 474,
#   'UNIGRAM_gums': 475,
#   'UNIGRAM_internet': 476,
#   'UNIGRAM_command': 477,
#   'UNIGRAM_prompt': 478,
#   'UNIGRAM_list': 479,
#   'UNIGRAM_users': 480,
#   'UNIGRAM_as': 481,
#   'UNIGRAM_often': 482,
#   'UNIGRAM_wash': 483,
#   'UNIGRAM_yorkshire': 484,
#   'UNIGRAM_terrier': 485,
#   'UNIGRAM_mccain': 486,
#   'UNIGRAM_gonna': 487,
#   'UNIGRAM_9/11': 488,
#   'UNIGRAM_victims': 489,
#   'UNIGRAM_families': 490,
#   'UNIGRAM_answers': 491,
#   'UNIGRAM_they': 492,
#   'UNIGRAM_seek': 493,
#   'UNIGRAM_gets': 494,
#   'UNIGRAM_elected': 495,
#   'UNIGRAM_google': 496,
#   'UNIGRAM_drive': 497,
#   'UNIGRAM_king': 498,
#   'UNIGRAM_george': 499,
#   'UNIGRAM_iii': 500,
#   'UNIGRAM_care': 501,
#   'UNIGRAM_britain': 502,
#   'UNIGRAM_lost': 503,
#   'UNIGRAM_13': 504,
#   'UNIGRAM_american': 505,
#   'UNIGRAM_colonies': 506,
#   'UNIGRAM_1700': 507,
#   'UNIGRAM_fought': 508,
#   'UNIGRAM_&': 509,
#   'UNIGRAM_won': 510,
#   'UNIGRAM_war': 511,
#   'UNIGRAM_independence': 512,
#   'UNIGRAM_against': 513,
#   'UNIGRAM_denouncement': 514,
#   'UNIGRAM_/': 515,
#   'UNIGRAM_whistleblowing': 516,
#   'UNIGRAM_baby': 517,
#   'UNIGRAM_tooth': 518,
#   'UNIGRAM_adult': 519,
#   'UNIGRAM_recently': 520,
#   'UNIGRAM_men': 521,
#   'UNIGRAM_insight': 522,
#   'UNIGRAM_baffled': 523,
#   'UNIGRAM_wife': 524,
#   'UNIGRAM_told': 525,
#   'UNIGRAM_wants': 526,
#   'UNIGRAM_were': 527,
#   'UNIGRAM_messing': 528,
#   'UNIGRAM_around': 529,
#   'UNIGRAM_started': 530,
#   'UNIGRAM_bleeding': 531,
#   'UNIGRAM_best': 532,
#   'UNIGRAM_dragon': 533,
#   'UNIGRAM_ball': 534,
#   'UNIGRAM_game': 535,
#   'UNIGRAM_sick': 536,
#   'UNIGRAM_couple': 537,
#   'UNIGRAM_pictures': 538,
#   'UNIGRAM_claremont': 539,
#   'UNIGRAM_hotel': 540,
#   'UNIGRAM_blackpool': 541,
#   'UNIGRAM_keep': 542,
#   'UNIGRAM_one': 543,
#   'UNIGRAM_empty': 544,
#   'UNIGRAM_dns': 545,
#   'UNIGRAM_cache': 546,
#   'UNIGRAM_confuse': 547,
#   'UNIGRAM_wether': 548,
#   'UNIGRAM_bi': 549,
#   'UNIGRAM_gay': 550,
#   'UNIGRAM_who': 551,
#   'UNIGRAM_named': 552,
#   'UNIGRAM_orgasm': 553,
#   'UNIGRAM_anymore': 554,
#   'UNIGRAM_experienced': 555,
#   'UNIGRAM_several': 556,
#   'UNIGRAM_before': 557,
#   'UNIGRAM_matter': 558,
#   'UNIGRAM_hard': 559,
#   'UNIGRAM_try': 560,
#   'UNIGRAM_formula': 561,
#   'UNIGRAM_poop': 562,
#   'UNIGRAM_stains': 563,
#   'UNIGRAM_clothes': 564,
#   'UNIGRAM_books': 565,
#   'UNIGRAM_bible': 566,
#   'UNIGRAM_shrouded': 567,
#   'UNIGRAM_much': 568,
#   'UNIGRAM_mystery': 569,
#   "UNIGRAM_didn't": 570,
#   'UNIGRAM_dentist': 571,
#   'UNIGRAM_cast': 572,
#   'UNIGRAM_crown': 573,
#   'UNIGRAM_shoving': 574,
#   'UNIGRAM_random': 575,
#   'UNIGRAM_sized': 576,
#   'UNIGRAM_crowns': 577,
#   'UNIGRAM_write': 578,
#   'UNIGRAM_galatians': 579,
#   'UNIGRAM_2:20': 580,
#   'UNIGRAM_roman': 581,
#   'UNIGRAM_numerals': 582,
#   'UNIGRAM_marriage': 583,
#   'UNIGRAM_completion': 584,
#   'UNIGRAM_faith': 585,
#   'UNIGRAM_then': 586,
#   'UNIGRAM_many': 587,
#   'UNIGRAM_lie': 588,
#   'UNIGRAM_vote': 589,
#   'UNIGRAM_sure': 590,
#   'UNIGRAM_refering': 591,
#   'UNIGRAM_walter': 592,
#   'UNIGRAM_payton': 593,
#   'UNIGRAM_football': 594,
#   'UNIGRAM_card': 595,
#   'UNIGRAM_worth': 596,
#   'UNIGRAM_move': 597,
#   'UNIGRAM_new': 598,
#   'UNIGRAM_york': 599,
#   'UNIGRAM_scotland': 600,
#   'UNIGRAM_bag': 601,
#   'UNIGRAM_look': 602,
#   'UNIGRAM_inside': 603,
#   'UNIGRAM_long': 604,
#   'UNIGRAM_take': 605,
#   'UNIGRAM_liberty': 606,
#   'UNIGRAM_service': 607,
#   'UNIGRAM_release': 608,
#   'UNIGRAM_refund': 609,
#   'UNIGRAM_implantation': 610,
#   'UNIGRAM_weird': 611,
#   'UNIGRAM_3x': 612,
#   'UNIGRAM_+': 613,
#   'UNIGRAM_7': 614,
#   'UNIGRAM_28': 615,
#   'UNIGRAM_5': 616,
#   'UNIGRAM_=': 617,
#   'UNIGRAM_9': 618,
#   'UNIGRAM_cool': 619,
#   'UNIGRAM_chicago': 620,
#   'UNIGRAM_high': 621,
#   'UNIGRAM_house': 622,
#   'UNIGRAM_stuf': 623,
#   'UNIGRAM_any': 624,
#   'UNIGRAM_country': 625,
#   'UNIGRAM_separate': 626,
#   'UNIGRAM_laws': 627,
#   'UNIGRAM_india': 628,
#   'UNIGRAM_minorities': 629,
#   'UNIGRAM_jack': 630,
#   'UNIGRAM_johnson': 631,
#   'UNIGRAM_sightings': 632,
#   'UNIGRAM_refineries': 633,
#   'UNIGRAM_corpus': 634,
#   'UNIGRAM_christi': 635,
#   'UNIGRAM_area': 636,
#   'UNIGRAM_ex': 637,
#   'UNIGRAM_convicts': 638,
#   'UNIGRAM_black': 639,
#   "UNIGRAM_don't": 640,
#   'UNIGRAM_smile': 641,
#   'UNIGRAM_picture': 642,
#   'UNIGRAM_taken': 643,
#   'UNIGRAM_scene': 644,
#   'UNIGRAM_synonymous': 645,
#   'UNIGRAM_europe': 646,
#   'UNIGRAM_distant': 647,
#   'UNIGRAM_future': 648,
#   'UNIGRAM_temperature': 649,
#   'UNIGRAM_set': 650,
#   'UNIGRAM_oven': 651,
#   'UNIGRAM_baked': 652,
#   'UNIGRAM_potatos': 653,
#   'UNIGRAM_name': 654,
#   'UNIGRAM_10': 655,
#   'UNIGRAM_kids': 656,
#   'UNIGRAM_optimistic': 657,
#   'UNIGRAM_realistic': 658,
#   'UNIGRAM_life': 659,
#   'UNIGRAM_symptoms': 660,
#   'UNIGRAM_something': 661,
#   'UNIGRAM_feet': 662,
#   'UNIGRAM_away': 663,
#   'UNIGRAM_wall': 664,
#   'UNIGRAM_every': 665,
#   'UNIGRAM_half': 666,
#   'UNIGRAM_distance': 667,
#   'UNIGRAM_between': 668,
#   'UNIGRAM_hey': 669,
#   'UNIGRAM_smoking': 670,
#   'UNIGRAM_weed': 671,
#   'UNIGRAM_satellite': 672,
#   'UNIGRAM_mass': 673,
#   'UNIGRAM_310': 674,
#   'UNIGRAM_kg': 675,
#   'UNIGRAM_moves': 676,
#   'UNIGRAM_circular': 677,
#   'UNIGRAM_orbit': 678,
#   'UNIGRAM_3.00': 679,
#   'UNIGRAM_107': 680,
#   'UNIGRAM_m': 681,
#   'UNIGRAM_above': 682,
#   "UNIGRAM_earth's": 683,
#   'UNIGRAM_surface': 684,
#   'UNIGRAM_steam': 685,
#   'UNIGRAM_online': 686,
#   'UNIGRAM_play': 687,
#   'UNIGRAM_counter': 688,
#   'UNIGRAM_strike': 689,
#   'UNIGRAM_heart': 690,
#   'UNIGRAM_disease': 691,
#   'UNIGRAM_18': 692,
#   'UNIGRAM_years': 693,
#   'UNIGRAM_old': 694,
#   'UNIGRAM_width': 695,
#   'UNIGRAM_rectangle': 696,
#   'UNIGRAM_12': 697,
#   'UNIGRAM_units': 698,
#   'UNIGRAM_less': 699,
#   'UNIGRAM_length': 700,
#   'UNIGRAM_bigger': 701,
#   'UNIGRAM_breasts': 702,
#   'UNIGRAM_those': 703,
#   'UNIGRAM_metal': 704,
#   'UNIGRAM_things': 705,
#   'UNIGRAM_overbites': 706,
#   'UNIGRAM_called': 707,
#   'UNIGRAM_confused': 708,
#   'UNIGRAM_bridal': 709,
#   'UNIGRAM_ambika': 710,
#   'UNIGRAM_pillai': 711,
#   'UNIGRAM_lakme': 712,
#   'UNIGRAM_plz': 713,
#   'UNIGRAM_advice': 714,
#   'UNIGRAM_say': 715,
#   'UNIGRAM_interview': 716,
#   'UNIGRAM_family': 717,
#   'UNIGRAM_feud': 718,
#   'UNIGRAM_win': 719,
#   'UNIGRAM_first': 720,
#   'UNIGRAM_three': 721,
#   'UNIGRAM_rounds': 722,
#   'UNIGRAM_site': 723,
#   'UNIGRAM_dowlnload': 724,
#   'UNIGRAM_aami': 725,
#   'UNIGRAM_che': 726,
#   'UNIGRAM_tumar': 727,
#   'UNIGRAM_bhool': 728,
#   'UNIGRAM_bhulaiya': 729,
#   'UNIGRAM_weight': 730,
#   'UNIGRAM_lifter': 731,
#   'UNIGRAM_raises': 732,
#   'UNIGRAM_175': 733,
#   'UNIGRAM_barbell': 734,
#   'UNIGRAM_height': 735,
#   'UNIGRAM_1.95': 736,
#   'UNIGRAM_increase': 737,
#   'UNIGRAM_potential': 738,
#   'UNIGRAM_energy': 739,
#   'UNIGRAM_600': 740,
#   'UNIGRAM_pound': 741,
#   'UNIGRAM_cherry': 742,
#   'UNIGRAM_log': 743,
#   'UNIGRAM_6': 744,
#   'UNIGRAM_ft': 745,
#   'UNIGRAM_1': 746,
#   'UNIGRAM_wide': 747,
#   'UNIGRAM_rocky': 748,
#   'UNIGRAM_terain': 749,
#   'UNIGRAM_consider': 750,
#   'UNIGRAM_14': 751,
#   'UNIGRAM_year': 752,
#   'UNIGRAM_phenomenon': 753,
#   'UNIGRAM_products': 754,
#   'UNIGRAM_hybrid': 755,
#   'UNIGRAM_cross': 756,
#   'UNIGRAM_hardier': 757,
#   'UNIGRAM_either': 758,
#   'UNIGRAM_species': 759,
#   'UNIGRAM_produced': 760,
#   'UNIGRAM_them': 761,
#   'UNIGRAM_toilet': 762,
#   'UNIGRAM_paper': 763,
#   'UNIGRAM_holder': 764,
#   'UNIGRAM_down': 765,
#   'UNIGRAM_toile': 766,
#   'UNIGRAM_beers': 767,
#   'UNIGRAM_sell': 768,
#   'UNIGRAM_frank': 769,
#   'UNIGRAM_erwin': 770,
#   'UNIGRAM_center': 771,
#   'UNIGRAM_indian': 772,
#   'UNIGRAM_belong': 773,
#   'UNIGRAM_soon': 774,
#   'UNIGRAM_arabic': 775,
#   'UNIGRAM_feminine': 776,
#   'UNIGRAM_plurals': 777,
#   'UNIGRAM_lube': 778,
#   'UNIGRAM_mixtures': 779,
#   'UNIGRAM_explain': 780,
#   'UNIGRAM_programming': 781,
#   'UNIGRAM_naming': 782,
#   'UNIGRAM_standards': 783,
#   'UNIGRAM_differ': 784,
#   'UNIGRAM_diff': 785,
#   'UNIGRAM_languages': 786,
#   'UNIGRAM_missing': 787,
#   'UNIGRAM_youth': 788,
#   'UNIGRAM_members': 789,
#   'UNIGRAM_electoral': 790,
#   'UNIGRAM_reckon': 791,
#   'UNIGRAM_flog': 792,
#   'UNIGRAM_nani': 793,
#   'UNIGRAM_happens': 794,
#   'UNIGRAM_takes': 795,
#   'UNIGRAM_fiber': 796,
#   'UNIGRAM_body': 797,
#   'UNIGRAM_hopes': 798,
#   'UNIGRAM_law': 799,
#   'UNIGRAM_thermodynamics': 800,
#   'UNIGRAM_asian': 801,
#   'UNIGRAM_women': 802,
#   'UNIGRAM_dually': 803,
#   'UNIGRAM_image': 804,
#   'UNIGRAM_virgin': 805,
#   'UNIGRAM_dp': 806,
#   'UNIGRAM_masters': 807,
#   'UNIGRAM_wrong': 808,
#   'UNIGRAM_parents': 809,
#   'UNIGRAM_whatever': 810,
#   'UNIGRAM_younger': 811,
#   'UNIGRAM_very': 812,
#   'UNIGRAM_seldomly': 813,
#   'UNIGRAM_older': 814,
#   'UNIGRAM_seriously': 815,
#   'UNIGRAM_procedure': 816,
#   'UNIGRAM_after': 817,
#   'UNIGRAM_uae': 818,
#   'UNIGRAM_visit': 819,
#   'UNIGRAM_visa': 820,
#   'UNIGRAM_deal': 821,
#   'UNIGRAM_americans': 822,
#   'UNIGRAM_feel': 823,
#   'UNIGRAM_secretly': 824,
#   'UNIGRAM_corrupt': 825,
#   'UNIGRAM_demagogues': 826,
#   'UNIGRAM_politicians': 827,
#   'UNIGRAM_16gb': 828,
#   'UNIGRAM_micro': 829,
#   'UNIGRAM_sd': 830,
#   'UNIGRAM_ur': 831,
#   'UNIGRAM_top': 832,
#   'UNIGRAM_yaoi': 833,
#   "UNIGRAM_manga's": 834,
#   'UNIGRAM_macbook': 835,
#   'UNIGRAM_pro': 836,
#   'UNIGRAM_starting': 837,
#   'UNIGRAM_36': 838,
#   'UNIGRAM_gallon': 839,
#   'UNIGRAM_bow': 840,
#   'UNIGRAM_front': 841,
#   'UNIGRAM_fish': 842,
#   'UNIGRAM_tank': 843,
#   'UNIGRAM_cloudy': 844,
#   'UNIGRAM_stephen': 845,
#   'UNIGRAM_austin': 846,
#   'UNIGRAM_actually': 847,
#   'UNIGRAM_texas': 848,
#   'UNIGRAM_power': 849,
#   'UNIGRAM_ac': 850,
#   'UNIGRAM_radio': 851,
#   'UNIGRAM_radiator': 852,
#   'UNIGRAM_fan': 853,
#   'UNIGRAM_america': 854,
#   'UNIGRAM_place': 855,
#   'UNIGRAM_shitty': 856,
#   'UNIGRAM_jobs': 857,
#   'UNIGRAM_receive': 858,
#   'UNIGRAM_text': 859,
#   'UNIGRAM_messages': 860,
#   'UNIGRAM_sort': 861,
#   'UNIGRAM_device': 862,
#   'UNIGRAM_diet': 863,
#   'UNIGRAM_plan': 864,
#   'UNIGRAM_fine': 865,
#   'UNIGRAM_spanish': 866,
#   'UNIGRAM_easy': 867,
#   'UNIGRAM_points': 868,
#   'UNIGRAM_ears': 869,
#   'UNIGRAM_sore': 870,
#   'UNIGRAM_pierced': 871,
#   'UNIGRAM_webcams': 872,
#   'UNIGRAM_messenger': 873,
#   'UNIGRAM_conceptually': 874,
#   'UNIGRAM_definite': 875,
#   'UNIGRAM_integral': 876,
#   'UNIGRAM_function': 877,
#   'UNIGRAM_underneath': 878,
#   'UNIGRAM_curve': 879,
#   'UNIGRAM_school': 880,
#   'UNIGRAM_step': 881,
#   'UNIGRAM_dandruff': 882,
#   'UNIGRAM_igneous': 883,
#   'UNIGRAM_rocks': 884,
#   'UNIGRAM_happened': 885,
#   'UNIGRAM_falcons': 886,
#   'UNIGRAM_said': 887,
#   'UNIGRAM_virus': 888,
#   'UNIGRAM_account': 889,
#   'UNIGRAM_sent': 890,
#   'UNIGRAM_bunch': 891,
#   'UNIGRAM_e-mails': 892,
#   'UNIGRAM_didn': 893,
#   'UNIGRAM_fix': 894,
#   'UNIGRAM_received': 895,
#   'UNIGRAM_spiritual': 896,
#   'UNIGRAM_perception': 897,
#   'UNIGRAM_coveting': 898,
#   'UNIGRAM_stealing': 899,
#   'UNIGRAM_pronounce': 900,
#   'UNIGRAM_looking': 901,
#   'UNIGRAM_opinions': 902,
#   'UNIGRAM_channels': 903,
#   'UNIGRAM_eurovision': 904,
#   'UNIGRAM_presented': 905,
#   'UNIGRAM_trading': 906,
#   'UNIGRAM_entei': 907,
#   'UNIGRAM_mewtwo': 908,
#   'UNIGRAM_raiku': 909,
#   'UNIGRAM_punchs': 910,
#   'UNIGRAM_head': 911,
#   'UNIGRAM_paint': 912,
#   'UNIGRAM_cover': 913,
#   'UNIGRAM_miles': 914,
#   'UNIGRAM_website': 915,
#   'UNIGRAM_cost': 916,
#   'UNIGRAM_maintain': 917,
#   'UNIGRAM_various': 918,
#   'UNIGRAM_breeds': 919,
#   'UNIGRAM_acid': 920,
#   'UNIGRAM_bases': 921,
#   'UNIGRAM_clarification': 922,
#   'UNIGRAM_repair': 923,
#   'UNIGRAM_hole': 924,
#   'UNIGRAM_carpet': 925,
#   'UNIGRAM_improve': 926,
#   'UNIGRAM_english': 927,
#   'UNIGRAM_freeze': 928,
#   'UNIGRAM_bisquick': 929,
#   'UNIGRAM_mixes': 930,
#   'UNIGRAM_dose': 931,
#   'UNIGRAM_hit': 932,
#   'UNIGRAM_chemistry': 933,
#   'UNIGRAM_titrations': 934,
#   'UNIGRAM_buffers': 935,
#   'UNIGRAM_having': 936,
#   'UNIGRAM_grasping': 937,
#   'UNIGRAM_labour': 938,
#   'UNIGRAM_court': 939,
#   'UNIGRAM_effective': 940,
#   'UNIGRAM_especially': 941,
#   'UNIGRAM_mumbai': 942,
#   'UNIGRAM_atheism': 943,
#   'UNIGRAM_religion': 944,
#   'UNIGRAM_lawyer': 945,
#   "UNIGRAM_she's": 946,
#   'UNIGRAM_corpse': 947,
#   'UNIGRAM_register': 948,
#   'UNIGRAM_9th': 949,
#   'UNIGRAM_grade': 950,
#   'UNIGRAM_8th': 951,
#   'UNIGRAM_turntable': 952,
#   'UNIGRAM_speakers': 953,
#   'UNIGRAM_apps': 954,
#   'UNIGRAM_info': 955,
#   'UNIGRAM_ipad': 956,
#   'UNIGRAM_mahindra': 957,
#   'UNIGRAM_bolero': 958,
#   'UNIGRAM_2wd': 959,
#   'UNIGRAM_converted': 960,
#   'UNIGRAM_into': 961,
#   'UNIGRAM_4': 962,
#   'UNIGRAM_wheel': 963,
#   'UNIGRAM_insignificant': 964,
#   'UNIGRAM_pointless': 965,
#   'UNIGRAM_white': 966,
#   'UNIGRAM_lies': 967,
#   'UNIGRAM_shops': 968,
#   'UNIGRAM_open': 969,
#   'UNIGRAM_late': 970,
#   'UNIGRAM_manchester': 971,
#   'UNIGRAM_today': 972,
#   'UNIGRAM_justin': 973,
#   'UNIGRAM_bieber': 974,
#   'UNIGRAM_meet': 975,
#   'UNIGRAM_greet': 976,
#   'UNIGRAM_2013': 977,
#   'UNIGRAM_downloaded': 978,
#   'UNIGRAM_avast': 979,
#   'UNIGRAM_antivirus': 980,
#   'UNIGRAM_program': 981,
#   'UNIGRAM_once': 982,
#   'UNIGRAM_realize': 983,
#   'UNIGRAM_group': 984,
#   'UNIGRAM_friends': 985,
#   'UNIGRAM_backstabbing': 986,
#   'UNIGRAM_biatches': 987,
#   'UNIGRAM_big': 988,
#   'UNIGRAM_again': 989,
#   'UNIGRAM_stick': 990,
#   'UNIGRAM_tongue': 991,
#   'UNIGRAM_behind': 992,
#   'UNIGRAM_tonsils': 993,
#   'UNIGRAM_rare': 994,
#   'UNIGRAM_lot': 995,
#   'UNIGRAM_cycle': 996,
#   'UNIGRAM_ovulate': 997,
#   'UNIGRAM_note': 998,
#   'UNIGRAM_says': 999,
#   ...})
